# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka2711/FACE_RECOGNITION_ANUSHKA/blob/master/my_notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2ef7a11-8595-4e4c-b168-c7ecc8c6e8cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2ef7a11-8595-4e4c-b168-c7ecc8c6e8cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Video 2020-08-23 at 9.27.20 PM.mp4 to WhatsApp Video 2020-08-23 at 9.27.20 PM.mp4

# %%
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("/content/WhatsApp Video 2020-08-23 at 9.27.20 PM.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('data'): 
        os.makedirs('data') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './data/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../data/frame0.jpg
# Creating..../data/frame1.jpg
# Creating..../data/frame2.jpg
# Creating..../data/frame3.jpg
# Creating..../data/frame4.jpg
# Creating..../data/frame5.jpg
# Creating..../data/frame6.jpg
# Creating..../data/frame7.jpg
# Creating..../data/frame8.jpg
# Creating..../data/frame9.jpg
# Creating..../data/frame10.jpg
# Creating..../data/frame11.jpg
# Creating..../data/frame12.jpg
# Creating..../data/frame13.jpg
# Creating..../data/frame14.jpg
# Creating..../data/frame15.jpg
# Creating..../data/frame16.jpg
# Creating..../data/frame17.jpg
# Creating..../data/frame18.jpg
# Creating..../data/frame19.jpg
# Creating..../data/frame20.jpg
# Creating..../data/frame21.jpg
# Creating..../data/frame22.jpg
# Creating..../data/frame23.jpg
# Creating..../data/frame24.jpg
# Creating..../data/frame25.jpg
# Creating..../data/frame26.jpg
# Creating..../data/frame27.jpg
# Creating..../data/frame28.jpg
# Creating..../data/frame29.jpg
# Creating..../data/frame30.jpg
# ...

# %%
os.makedirs("/content/me")

# %%
import dlib
import cv2
import os
from imutils import face_utils
from PIL import Image
face_detector = dlib.get_frontal_face_detector()   
def shape_to_list(shape):
    coords = []
    for i in range(0, 68):
        coords.append((shape.part(i).x, shape.part(i).y))
    return coords
def face_finder(image_link):
  img=cv2.imread(image_link)
  frame = img
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  rects = face_detector(gray,0)
  data=[]
  for rect in rects:
    (x1,y1,x2,y2) = face_utils.rect_to_bb(rect) 
    data.append([x1,y1,x2,y2])
  return face_cropper(image_link,data)
def face_cropper(image_link,rects):
  cropped_images=[]
  for rect in rects:
    my_image=Image.open(image_link)
    x1=rect[0]
    y1=rect[1]
    x2=rect[2]
    y2=rect[3]
    cropped_images.append(my_image.crop((x1,y1,x1+x2,y1+y2)))
  return cropped_images

# %%
x=os.listdir("/content/data")
i=0
while i<len(x):
 if os.path.isfile("/content/data/frame"+str(i)+".jpg"):
   colorImage  = Image.open("/content/data/frame"+str(i)+".jpg")
   transposed  = colorImage.transpose(Image.ROTATE_270)
   transposed.save("/content/me/anushka"+str(i)+".jpg")
 i+=1

# %%
#files.append(file)
import shutil, os
files=[]
for file in os.listdir("/content/me"):
 files.append(file)

# %%
files
# Out:
# ['anushka44.jpg',
#  'anushka221.jpg',
#  'anushka7.jpg',
#  'anushka218.jpg',
#  'anushka68.jpg',
#  'anushka46.jpg',
#  'anushka238.jpg',
#  'anushka25.jpg',
#  'anushka284.jpg',
#  'anushka185.jpg',
#  'anushka4.jpg',
#  'anushka252.jpg',
#  'anushka290.jpg',
#  'anushka203.jpg',
#  'anushka258.jpg',
#  'anushka93.jpg',
#  'anushka35.jpg',
#  'anushka222.jpg',
#  'anushka298.jpg',
#  'anushka126.jpg',
#  'anushka275.jpg',
#  'anushka142.jpg',
#  'anushka256.jpg',
#  'anushka201.jpg',
#  'anushka186.jpg',
#  'anushka187.jpg',
#  'anushka209.jpg',
#  'anushka54.jpg',
#  'anushka229.jpg',
#  'anushka197.jpg',
#  'anushka251.jpg',
#  'anushka29.jpg',
#  'anushka33.jpg',
#  'anushka220.jpg',
#  'anushka198.jpg',
#  'anushka246.jpg',
#  'anushka165.jpg',
#  'anushka240.jpg',
#  'anushka95.jpg',
#  'anushka116.jpg',
#  'anushka282.jpg',
#  'anushka36.jpg',
#  'anushka245.jpg',
#  'anushka236.jpg',
#  'anushka253.jpg',
#  'anushka219.jpg',
#  'anushka180.jpg',
#  'anushka135.jpg',
# ...

# %%
files[0]
# Out:
# 'anushka44.jpg'

# %%
img=face_finder("/content/me/anushka194.jpg")

# %%
img[0]
# Out:
# <PIL.Image.Image image mode=RGB size=149x149 at 0x7F0E447DF160>

# %%
face_finder("/content/me/anushka"+str(194)+".jpg")
# Out:
# [<PIL.Image.Image image mode=RGB size=149x149 at 0x7F0E3ACAF400>]

# %%
#os.makedirs("/content/cropped/anushka")

# %%
fans=[]
i=0
for x in range(0,len(files)):
  fans.append(face_finder("/content/me/anushka"+str(i)+".jpg"))
  i+=1
i=0
for x in range(0,len(fans)):
  if len(fans[x])==0:
    continue
  else:
    fans[x][0].save("/content/me/anushka"+str(i)+".jpg")
    i+=1

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-9bcc674c-57b0-4024-94c1-c52c34cd6060" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bcc674c-57b0-4024-94c1-c52c34cd6060">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
import os
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %%
# !kaggle datasets download -d hereisburak/pins-face-recognition
# Out:
# ...
#  95% 352M/372M [00:09<00:00, 48.2MB/s]
# 100% 372M/372M [00:09<00:00, 40.6MB/s]

# %%
# !unzip "*.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner38_965.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner39_966.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner3_956.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner41_968.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner42_969.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner44_970.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner45_971.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner46_972.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner47_973.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner48_974.jpg
#   inflating: 105_classes_pins_dataset/pins_Sophie Turner/Sophie Turner49_975.jpg
# ...

# %%
os.makedirs('notme')

# %%
inm=[]
j=0
tfiles=os.listdir("/content/105_classes_pins_dataset")
for file in tfiles:
  tfile1=os.listdir("/content/105_classes_pins_dataset/"+file)
  i=0
  for x in tfile1:
    if i==40:
      break
    else:
      colorImage  = Image.open("/content/105_classes_pins_dataset/"+file+"/"+x)
      #os.makedirs("/content/itsnotme/anushka"+str(j)+".jpg")
      colorImage.save("/content/notme/anushka"+str(j)+".jpg")
      i+=1
      j+=1

# %%
os.makedirs("/content/my_dataset")

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
shutil.move("/content/me", "/content/my_dataset")
# Out:
# '/content/my_dataset/me'

# %%
shutil.move("/content/notme", "/content/my_dataset")
# Out:
# '/content/my_dataset/notme'

# %%
path=""
tfms = get_transforms()
data = ImageDataBunch.from_folder( Path("my_dataset"), valid_pct=0.2, bs=64, size=224, ds_tfms=get_transforms())
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.show_batch(rows=10, figsize=(15,15))

# %%
print(data.classes)
len(data.classes)
# Out:
# ['me', 'notme']
# 2

# %%
# !kaggle datasets init -p "/content/my_dataset"
# Out:
# Data package template written to: /content/my_dataset/dataset-metadata.json

# %%
resnet_learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
resnet_learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.578413</td>
#       <td>0.132521</td>
#       <td>0.048780</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.205236</td>
#       <td>0.013764</td>
#       <td>0.001109</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.093052</td>
#       <td>0.005535</td>
#       <td>0.000000</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.054429</td>
#       <td>0.003889</td>
#       <td>0.000000</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4227aa49-1e27-4b80-bb32-ed831a78541a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4227aa49-1e27-4b80-bb32-ed831a78541a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PHOTO.JPEG to PHOTO.JPEG

# %%
test_image1 =open_image("/content/PHOTO.JPEG")
test_image1
# Out:
# Image (3, 612, 588)

# %%
import dlib
import cv2
import os

from imutils import face_utils
from PIL import Image
face_detector = dlib.get_frontal_face_detector()   
def shape_to_list(shape):
    coords = []
    for i in range(0, 68):
        coords.append((shape.part(i).x, shape.part(i).y))
    return coords
def face_finder(image_link):
  img=cv2.imread(image_link)
  frame = img
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  rects = face_detector(gray,0)
  data=[]
  for rect in rects:
    (x1,y1,x2,y2) = face_utils.rect_to_bb(rect) 
    data.append([x1,y1,x2,y2])
  return face_cropper(image_link,data)
def face_cropper(image_link,rects):
  cropped_images=[]
  for rect in rects:
    my_image=Image.open(image_link)
    x1=rect[0]
    y1=rect[1]
    x2=rect[2]
    y2=rect[3]
    cropped_images.append(my_image.crop((x1,y1,x1+x2,y1+y2)))
  return cropped_images

# %%
test_face = face_finder("/content/PHOTO.JPEG")
test_face[0].save("test_face1.jpeg")
test_face[0]
# Out:
# <PIL.Image.Image image mode=RGB size=179x179 at 0x7F0271985C50>

# %%
my_image1 = open_image("test_face1.jpeg")

# %%
# %%time
pred_class,pred_idx,outputs = resnet_learn.predict(my_image1)
print(pred_class)
# Out:
# notme
# CPU times: user 26 ms, sys: 2.95 ms, total: 29 ms
# Wall time: 29 ms

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-179e9374-7426-47b7-bd5f-97a74dbe0bc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-179e9374-7426-47b7-bd5f-97a74dbe0bc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.jpeg to test.jpeg

# %%
test_image2 =open_image("/content/test.jpeg")
test_image2
# Out:
# Image (3, 1170, 540)

# %%
test_face = face_finder("/content/test.jpeg")
test_face[0].save("test_face2.jpeg")
test_face[0]
# Out:
# <PIL.Image.Image image mode=RGB size=258x258 at 0x7F0271985D30>

# %%
my_image2 = open_image("test_face2.jpeg")

# %%
# %%time
pred_class,pred_idx,outputs = resnet_learn.predict(my_image2)
print(pred_class)
# Out:
# me
# CPU times: user 23.9 ms, sys: 4.94 ms, total: 28.9 ms
# Wall time: 28.9 ms
